# %% [markdown]
# <a href="https://colab.research.google.com/github/tarakaashree/Customer_Churn_Prediction/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#OBJECTIVE - Customer Churn Prediction: Using historical customer data to predict which user is likely to stop buying product from a company
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b8d901f2-0af5-4ac2-897e-d7a68447b620" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b8d901f2-0af5-4ac2-897e-d7a68447b620">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Phase1- Loading and Understanding Dataset
import pandas as pd
churn=pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
churn.head()
print(churn.columns)
print(churn.shape) #7043 Rows and 21 Columns
churn.info()
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')
# (7043, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
# ...

# %%
#Phase2- Data Cleaning
print(churn.isnull().sum()) #no null values
print(churn.duplicated().sum()) #no duplicated values
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64
# 0

# %%
#Phase3- EDA and Data Visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#UNIVARIANTE ANALYSIS:

# %%
gender_basis=churn['gender'].value_counts()
plt.pie(gender_basis, labels=gender_basis.index, autopct='%1.1f') # 1% more male than female
# Out:
# ([<matplotlib.patches.Wedge at 0x7ea2c5c8c110>,
# ...
#  [Text(-0.016436740380449354, 1.099877190219738, 'Male'),
#   Text(0.016436836534770922, -1.0998771887827883, 'Female')],
#  [Text(-0.008965494752972375, 0.5999330128471297, '50.5'),
#   Text(0.008965547200784138, -0.599933012063339, '49.5')])

# %%
plt.figure(figsize=(10,10))
plt.grid()
plt.xlabel('No of months')
plt.ylabel('No of Customers')
plt.hist(churn['tenure'],bins=20)
#there are more than 1000 customers who have tenure of less than 10
#there are more than 700 customers who have tenure of more than 60
# Out:
# (array([1062.,  550.,  358.,  401.,  266.,  304.,  348.,  208.,  278.,
#          217.,  230.,  264.,  186.,  266.,  218.,  277.,  279.,  222.,
#          363.,  746.]),
#  array([ 0. ,  3.6,  7.2, 10.8, 14.4, 18. , 21.6, 25.2, 28.8, 32.4, 36. ,
#         39.6, 43.2, 46.8, 50.4, 54. , 57.6, 61.2, 64.8, 68.4, 72. ]),
#  <BarContainer object of 20 artists>)

# %%
sns.countplot(data=churn,x='Contract')
sns.set_style('darkgrid')
#there are higher no.of Customers with monthly contract followed by 2yrs contract and then 1yr.

# %%
plt.figure(figsize=(10,10))
sns.countplot(data=churn,x='PaymentMethod')
#large no.of customers are using Electronic check as payment method
# Out:
# <Axes: xlabel='PaymentMethod', ylabel='count'>

# %%
sns.countplot(data=churn,x='InternetService')
plt.xlabel('Type of Internet service')
plt.ylabel('No of Customers')
#more than 3000 customers are using fiber optics as their type of internet service
# Out:
# Text(0, 0.5, 'No of Customers')

# %%
plt.pie(churn['TechSupport'].value_counts(),labels=churn['TechSupport'].value_counts().index,autopct='%1.1f')
#most of the people do not have tech support
# Out:
# ([<matplotlib.patches.Wedge at 0x7ea2c42bc5f0>,
# ...
#  [Text(0.023795345485305243, 1.0997425978533502, 'No'),
#   Text(-0.7105890970039966, -0.8396803768214693, 'Yes'),
#   Text(0.854855425298623, -0.6922587679744552, 'No internet service')],
#  [Text(0.01297927935562104, 0.5998595988291, '49.3'),
#   Text(-0.38759405291127086, -0.45800747826625593, '29.0'),
#   Text(0.4662847774356125, -0.37759569162243006, '21.7')])

# %%
plt.bar(churn['Churn'].value_counts().index,churn['Churn'].value_counts())
#there are less no.of customers who have churn
# Out:
# <BarContainer object of 2 artists>

# %%
#HOW EACH FEATURE CONTRIBUTE TO DECIDING CHURN?
#Gender- by analyzing no of male and female we can analyse who is more likely to churn
#Tenure- by analyzing how long a customer stays in , we decide who is more likely to churn(more tenure less likely to churn)
#Contract- by analyzing Contract period we can decide who is choosing us for long period and who is not
#Payment Method- by analyzing which Method of payment more people are convenient with we can offer that type of mode more flexible
#Internet service- by analyzing the if customer have the service or not, we can offer them the service to attract more customers
#Tech Support- we can offer support to customers to attract more no.of Customers

# %%
#BIVARIANTE ANALYSIS:

# %%
#So far we have analysed only the single feature. Now we will try to correlate features with one another to look at how they affect each other.

# %%
#Gender vs Churn
sns.countplot(data=churn,x='gender',hue='Churn') #Gender do not greatly affect Churn
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
#Tenure vs Churn
tenure_by_churn=churn.groupby('Churn')['tenure'].mean()
tenure_by_churn.plot(kind='bar') # long time customers are less likely to churn
# Out:
# <Axes: xlabel='Churn'>

# %%
#Contract vs Churn
sns.countplot(data=churn,x='Contract',hue='Churn') #month-month contract customer are more likely to churn
# Out:
# <Axes: xlabel='Contract', ylabel='count'>

# %%
#Payment method vs Churn
sns.countplot(data=churn,x='PaymentMethod',hue='Churn') #electronic check method is more likely to churn
# Out:
# <Axes: xlabel='PaymentMethod', ylabel='count'>

# %%
#Internet Service vs Churn
sns.countplot(data=churn,x='InternetService',hue='Churn') #fiber optics is more likely to churn
# Out:
# <Axes: xlabel='InternetService', ylabel='count'>

# %%
#Tech Support vs Churn
sns.countplot(data=churn,x='TechSupport',hue='Churn') #most customers who don't get tech support are likely to churn
# Out:
# <Axes: xlabel='TechSupport', ylabel='count'>

# %%
#Phase4- Modelling

# %%
from sklearn.preprocessing import OneHotEncoder
categories=['gender','InternetService','TechSupport','Contract','PaymentMethod']
encoder=OneHotEncoder(handle_unknown='ignore', sparse_output=False)
encoded_value=encoder.fit_transform(churn[categories])
encoded_col=encoder.get_feature_names_out(categories)
data=pd.DataFrame(encoded_value,columns=encoded_col,index=churn.index)
churn_final=pd.concat([churn[['Churn','tenure']],data],axis=1)

# %%
x=churn_final.drop(['Churn'],axis=1)
y=churn_final[['Churn']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc_model=rfc.fit(x_train_scaled,y_train)
y_pred_rfc=rfc.predict(x_test_scaled)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred_rfc,y_test)
# Out:
# 0.7508871540099361

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(x_train_scaled,y_train)
y_pred_dtc=dtc.predict(x_test_scaled)

# %%
accuracy_score(y_pred_dtc,y_test)
# Out:
# 0.7395315826827538

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train_scaled,y_train)
y_pred_knn=knn.predict(x_test_scaled)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
accuracy_score(y_pred_knn,y_test)
# Out:
# 0.7665010645848119

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr_model=lr.fit(x_train_scaled,y_train)
y_pred_lr=lr.predict(x_test_scaled)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
accuracy_score(y_pred_lr,y_test)
# Out:
# 0.8026969481902059

# %%
#Logistic Regression has the highest accuracy score,so it is considered as the best model.

# %%
#Phase5- Save Model
import joblib

joblib.dump(encoder, "encoder.joblib")
# Out:
# ['encoder.joblib']

# %%
 joblib.dump(scaler, "scaler.joblib")
# Out:
# ['scaler.joblib']

# %%
joblib.dump(lr_model, "lr_model.joblib")
# Out:
# ['lr_model.joblib']

# %%
from google.colab import files

files.download("encoder.joblib")
files.download("lr_model.joblib")
files.download("scaler.joblib")
